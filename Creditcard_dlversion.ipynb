# %%
# !pip install pandas
# !pip install matplotlib seaborn plotly pandas
# !pip install matplotlib
# !pip install scikit-learn
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\asus\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\roaming\python\python312\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\asus\appdata\roaming\python\python312\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\asus\appdata\roaming\python\python312\site-packages (6.0.0)
# Requirement already satisfied: pandas in c:\users\asus\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from plotly) (1.30.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\roaming\python\python312\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\asus\appdata\roaming\python\python312\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
pd.options.display.max_columns = None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 284802 -0.689256  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920
# 284803  1.214756 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556
# 284804 -0.183699 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252
# 284805 -1.042082  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849
# 284806 -0.188093 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117
#
#              V20       V21       V22       V23       V24       V25       V26  \
# 284802  1.475829  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034
# 284803  0.059616  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of columns : {}".format(data.shape[1]))
print("Number of rows : {}".format(data.shape[0]))
# Out:
# Number of columns : 31
# Number of rows : 284807

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 4 X_scaled = scaler.fit_transform(X)
#
# NameError: name 'X' is not defined

# %%
sc = StandardScaler()
data['Amount'] = sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#      Amount  Class
# 0  0.244200      0
# 1 -0.342584      0
# 2  1.158900      0
# 3  0.139886      0
# 4 -0.073813      0

# %%
data = data.drop(['Time'] , axis = 1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#      Amount  Class
# 0  0.244200      0
# 1 -0.342584      0
# 2  1.158900      0
# 3  0.139886      0
# 4 -0.073813      0

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
sns.countplot(x='Class', data=data)
plt.show()

# %%
X = data.drop('Class' , axis = 1)
Y = data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score , f1_score , precision_score , recall_score

# %%
classifier = {
    "Logistic Regression": LogisticRegression() ,
    "Decision Tree Classifier": DecisionTreeClassifier()
}
for name , clf in classifier.items():
    print(f"\n============={name}===============")
    clf.fit(X_train , Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuracy: {accuracy_score(Y_test , Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test , Y_pred)}")
    print(f"\n Recall: { recall_score(Y_test , Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test , Y_pred)}")
# Out:
# =============Logistic Regression===============
#
#  Accuracy: 0.9992382057932636
#
#  Precision: 0.8769230769230769
#
#  Recall: 0.6263736263736264
#
#  F1 Score: 0.7307692307692307
#
# =============Decision Tree Classifier===============
#
#  Accuracy: 0.998911722561805
#
#  Precision: 0.6504854368932039
#
#  Recall: 0.7362637362637363
#
#  F1 Score: 0.6907216494845361

# %%
#undersampling 
normal = data[data['Class'] == 0 ]
fraud = data[data['Class'] == 1 ]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
#taking 
normal_sample = normal.sample(n = 473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample , fraud] , ignore_index = True)

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.307629  0.468745 -1.112900 -0.994263  1.421505  0.779768  0.339976
# 1 -3.166253 -0.807776  0.741713 -2.676264 -2.761004 -0.404470 -1.494162
# 2  1.507919 -1.262139 -0.909080  0.461785 -0.732005 -0.179303 -0.277884
# 3 -0.604753  1.470056 -0.305766 -0.876919  0.916493 -0.650211  1.338045
# 4 -1.983808 -0.952757  0.227990 -1.196704  0.764082 -1.065063  0.320364
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.571608  0.010125 -1.131583  1.172671  0.620995 -0.369371 -0.395444
# 1  1.363762 -1.698196  0.422161 -1.599830 -0.843174  0.881555 -0.162174
# 2  0.047730  1.453145 -0.198456 -1.334016 -0.691227 -1.661332  0.457603
# 3 -0.527047  0.740689  1.523213  0.855358  0.605246  0.285079 -0.163830
# 4  0.272709 -1.903281 -0.409425 -1.436654 -0.303402  0.263069  0.516465
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  0.294651  0.037988  0.432050 -0.155007 -1.969807 -0.393887  1.118044
# 1  0.495594  1.045547  0.164687  0.999400 -1.383361 -0.116219  0.108067
# 2  1.287196  0.576425 -0.675801  0.331202 -0.131190  0.236582 -0.025440
# 3 -0.097362 -0.481219 -1.049647  0.508875  0.262232  0.681202  0.190701
# 4 -0.407746 -1.590964  0.149121  0.844319 -0.607952  0.103385 -0.305069
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.821513 -0.239693 -1.708716  0.397794 -0.125433  0.278787  0.303700
# 1  0.322751 -0.528220 -0.096762  0.486059 -0.059482  0.271183 -0.153811
# 2 -0.697886  0.158490  0.385953 -0.549040 -0.654290 -0.035394  0.016037
# 3  1.413189 -0.217629 -0.361587 -0.627452 -0.254464  0.603272  0.103306
# 4 -1.263048  0.007477  0.650486  0.676872  0.557545 -0.192362 -0.222475
#
#      Amount  Class
# 0 -0.165746      0
# 1  0.256300      0
# 2  0.734856      0
# 3 -0.349773      0
# 4  0.159215      0

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X = new_data.drop('Class' , axis = 1)
Y = new_data['Class']

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression() ,
    "Decision Tree Classifier": DecisionTreeClassifier()
}
for name , clf in classifier.items():
    print(f"\n============={name}===============")
    clf.fit(X_train , Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuracy: {accuracy_score(Y_test , Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test , Y_pred)}")
    print(f"\n Recall: { recall_score(Y_test , Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test , Y_pred)}")
# Out:
# =============Logistic Regression===============
#
#  Accuracy: 0.9473684210526315
#
#  Precision: 0.9893617021276596
#
#  Recall: 0.9117647058823529
#
#  F1 Score: 0.9489795918367347
#
# =============Decision Tree Classifier===============
#
#  Accuracy: 0.9105263157894737
#
#  Precision: 0.9292929292929293
#
#  Recall: 0.9019607843137255
#
#  F1 Score: 0.9154228855721394

# %%
# see we did undersampling to balance our data so we got improvements in our F1 Score and other measurements as well
# Now , oversampling 
# Method used : SMOTE
X = data.drop('Class' , axis = 1 )
Y = data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
Y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res , Y_res = SMOTE().fit_resample(X , Y)

# %%
Y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
#now as we can see we have much more balanced amount of data for fraud and non fraud transactions 
#we can now simply apply the machine learning algorithms 
X_train , X_test , Y_train , Y_test = train_test_split(X_res , Y_res , test_size = 0.2 , random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression() ,
    "Decision Tree Classifier": DecisionTreeClassifier()
}
for name , clf in classifier.items():
    print(f"\n============={name}===============")
    clf.fit(X_train , Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuracy: {accuracy_score(Y_test , Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test , Y_pred)}")
    print(f"\n Recall: { recall_score(Y_test , Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test , Y_pred)}")
# Out:
# =============Logistic Regression===============
#
#  Accuracy: 0.9445201497147425
#
#  Precision: 0.9729551961618819
#
#  Recall: 0.9143864880097449
#
#  F1 Score: 0.9427620788228127
#
# =============Decision Tree Classifier===============
#
#  Accuracy: 0.997892365274901
#
#  Precision: 0.9972943035101418
#
#  Recall: 0.998490991400469
#
#  F1 Score: 0.9978922886837707

# %%
#Saving model
dtc = DecisionTreeClassifier()
dtc.fit(X_res , Y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc,"credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model = joblib.load("credit_card_model.pkl")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define the model
model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Train the model
history = model.fit(X_train, Y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 1ms/step - accuracy: 0.9614 - loss: 0.0962 - precision: 0.9652 - recall: 0.9577 - val_accuracy: 0.9969 - val_loss: 0.0120 - val_precision: 0.9938 - val_recall: 1.0000
# Epoch 2/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 16s 1ms/step - accuracy: 0.9957 - loss: 0.0158 - precision: 0.9931 - recall: 0.9983 - val_accuracy: 0.9985 - val_loss: 0.0066 - val_precision: 0.9971 - val_recall: 0.9999
# Epoch 3/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 16s 1ms/step - accuracy: 0.9971 - loss: 0.0112 - precision: 0.9956 - recall: 0.9986 - val_accuracy: 0.9989 - val_loss: 0.0058 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 4/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9976 - loss: 0.0095 - precision: 0.9963 - recall: 0.9989 - val_accuracy: 0.9994 - val_loss: 0.0043 - val_precision: 0.9988 - val_recall: 1.0000
# Epoch 5/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9981 - loss: 0.0075 - precision: 0.9971 - recall: 0.9991 - val_accuracy: 0.9990 - val_loss: 0.0049 - val_precision: 0.9981 - val_recall: 0.9998
# Epoch 6/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - accuracy: 0.9981 - loss: 0.0076 - precision: 0.9971 - recall: 0.9992 - val_accuracy: 0.9989 - val_loss: 0.0055 - val_precision: 0.9978 - val_recall: 1.0000
# Epoch 7/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9984 - loss: 0.0071 - precision: 0.9973 - recall: 0.9994 - val_accuracy: 0.9993 - val_loss: 0.0040 - val_precision: 0.9985 - val_recall: 1.0000
# Epoch 8/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9985 - loss: 0.0067 - precision: 0.9976 - recall: 0.9994 - val_accuracy: 0.9991 - val_loss: 0.0041 - val_precision: 0.9985 - val_recall: 0.9997
# Epoch 9/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9986 - loss: 0.0063 - precision: 0.9978 - recall: 0.9994 - val_accuracy: 0.9993 - val_loss: 0.0038 - val_precision: 0.9985 - val_recall: 1.0000
# Epoch 10/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9986 - loss: 0.0064 - precision: 0.9978 - recall: 0.9993 - val_accuracy: 0.9994 - val_loss: 0.0044 - val_precision: 0.9988 - val_recall: 1.0000
# Epoch 11/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9988 - loss: 0.0055 - precision: 0.9980 - recall: 0.9996 - val_accuracy: 0.9992 - val_loss: 0.0040 - val_precision: 0.9985 - val_recall: 1.0000
# Epoch 12/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9985 - loss: 0.0062 - precision: 0.9976 - recall: 0.9995 - val_accuracy: 0.9994 - val_loss: 0.0036 - val_precision: 0.9987 - val_recall: 1.0000
# Epoch 13/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9988 - loss: 0.0052 - precision: 0.9982 - recall: 0.9995 - val_accuracy: 0.9993 - val_loss: 0.0040 - val_precision: 0.9987 - val_recall: 1.0000
# Epoch 14/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9987 - loss: 0.0057 - precision: 0.9979 - recall: 0.9995 - val_accuracy: 0.9994 - val_loss: 0.0034 - val_precision: 0.9988 - val_recall: 1.0000
# Epoch 15/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9991 - loss: 0.0044 - precision: 0.9985 - recall: 0.9997 - val_accuracy: 0.9994 - val_loss: 0.0032 - val_precision: 0.9989 - val_recall: 0.9998
# Epoch 16/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9987 - loss: 0.0057 - precision: 0.9980 - recall: 0.9995 - val_accuracy: 0.9990 - val_loss: 0.0046 - val_precision: 0.9991 - val_recall: 0.9988
# Epoch 17/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9989 - loss: 0.0047 - precision: 0.9982 - recall: 0.9995 - val_accuracy: 0.9994 - val_loss: 0.0034 - val_precision: 0.9988 - val_recall: 1.0000
# Epoch 18/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9988 - loss: 0.0054 - precision: 0.9980 - recall: 0.9995 - val_accuracy: 0.9995 - val_loss: 0.0030 - val_precision: 0.9989 - val_recall: 1.0000
# Epoch 19/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.9990 - loss: 0.0052 - precision: 0.9984 - recall: 0.9996 - val_accuracy: 0.9995 - val_loss: 0.0030 - val_precision: 0.9991 - val_recall: 0.9999
# Epoch 20/20
# 11008/11008 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.9990 - loss: 0.0045 - precision: 0.9985 - recall: 0.9996 - val_accuracy: 0.9995 - val_loss: 0.0033 - val_precision: 0.9989 - val_recall: 1.0000

# %%
# this is to check if our model is actually working fine or not 
import matplotlib.pyplot as plt

# Plot training & validation accuracy/loss
plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate model
loss, accuracy, precision, recall = model.evaluate(X_test, Y_test)
f1_score_dl = 2 * (precision * recall) / (precision + recall)

print(f"\nAccuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score_dl}")
# Out:
# 3440/3440 ━━━━━━━━━━━━━━━━━━━━ 3s 965us/step - accuracy: 0.9994 - loss: 0.0031 - precision: 0.9988 - recall: 1.0000
#
# Accuracy: 0.9994821548461914
# Precision: 0.998964786529541
# Recall: 1.0
# F1 Score: 0.9994821252092908

# %%
model.save("credit_card_dl_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Prepare data for testing 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df.drop(['Class'], axis=1))
y_sample = df['Class'][:50].values
X_sample = X_scaled[:5]

# Make predictions
preds = model.predict(X_sample)

# Interpret predictions
for i, p in enumerate(preds):
    print(f"Transaction {i+1}: {'Fraud' if p > 0.5 else 'Normal'} (Actual: {'Fraud' if y_sample[i]==1 else 'Normal'})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Transaction 1: Normal (Actual: Normal)
# Transaction 2: Normal (Actual: Normal)
# Transaction 3: Normal (Actual: Normal)
# Transaction 4: Normal (Actual: Normal)
# Transaction 5: Normal (Actual: Normal)
